# %%
# Import required libraries and dependencies
import numpy as np
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
# Load the data into a Pandas DataFrame

df_music_genre = pd.read_csv(
    "Resources/music_genre.csv")

# Display sample data

df_music_genre.head(10)
# Out:
#    instance_id           artist_name            track_name  popularity  \
# 0      32894.0              Röyksopp  Röyksopp's Night Out        27.0
# 1      46652.0  Thievery Corporation      The Shining Path        31.0
# 2      30097.0        Dillon Francis             Hurricane        28.0
# 3      62177.0              Dubloadz                 Nitro        34.0
# 4      24907.0           What So Not      Divide & Conquer        32.0
# 5      89064.0            Axel Boman                 Hello        47.0
# 6      43760.0        Jordan Comolli                 Clash        46.0
# 7      30738.0                Hraach               Delirio        43.0
# 8      84950.0                 Kayzo           NEVER ALONE        39.0
# 9      56950.0                Shlump            Lazer Beam        22.0
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0       0.00468         0.652         -1.0   0.941          0.792000  A#
# ...

# %%
#Drop unncessary columns

df_music_genre = df_music_genre.drop(['instance_id', 'obtained_date'], axis=1)
df_music_genre.head()
# Out:
#             artist_name            track_name  popularity  acousticness  \
# 0              Röyksopp  Röyksopp's Night Out        27.0       0.00468
# 1  Thievery Corporation      The Shining Path        31.0       0.01270
# 2        Dillon Francis             Hurricane        28.0       0.00306
# 3              Dubloadz                 Nitro        34.0       0.02540
# 4           What So Not      Divide & Conquer        32.0       0.00465
#
#    danceability  duration_ms  energy  instrumentalness key  liveness  \
# 0         0.652         -1.0   0.941           0.79200  A#     0.115
# 1         0.622     218293.0   0.890           0.95000   D     0.124
# 2         0.620     215613.0   0.755           0.01180  G#     0.534
# 3         0.774     166875.0   0.700           0.00253  C#     0.157
# 4         0.638     222369.0   0.587           0.90900  F#     0.157
#
#    loudness   mode  speechiness               tempo  valence music_genre
# ...

# %%
# Encode the categorical variables using get_dummies
df_music_genre = pd.get_dummies(df_music_genre["key"])

df_music_genre.head()
#convert quantitative measurement 
#key, mode, music_genre
# Out:
#        A     A#      B      C     C#      D     D#      E      F     F#  \
# 0  False   True  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False   True  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False   True  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False   True
#
#        G     G#
# 0  False  False
# 1  False  False
# 2  False   True
# 3  False  False
# 4  False  False

# %%
### Scale dataframe

# %%
# Scale price data, return, and variance values
df_music_genre_scaled = StandardScaler().fit_transform(
    df_music_genre["popularity", "acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "liveness","loudness","speechiness","tempo","valence"]
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('popularity', 'acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'valence')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
x = df_music_genre["tempo"]
type(x[0])
# Out:
# str

# %%
columns = df_music_genre.columns
columns
# Out:
# Index(['artist_name', 'track_name', 'popularity', 'acousticness',
#        'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'valence',
#        'music_genre'],
#       dtype='object')

# %%
for col in columns:
    print(f"{col}'s dtype is {type(df_music_genre[col][0])}")
# Out:
# artist_name's dtype is <class 'str'>
# track_name's dtype is <class 'str'>
# popularity's dtype is <class 'numpy.float64'>
# acousticness's dtype is <class 'numpy.float64'>
# danceability's dtype is <class 'numpy.float64'>
# duration_ms's dtype is <class 'numpy.float64'>
# energy's dtype is <class 'numpy.float64'>
# instrumentalness's dtype is <class 'numpy.float64'>
# key's dtype is <class 'str'>
# liveness's dtype is <class 'numpy.float64'>
# loudness's dtype is <class 'numpy.float64'>
# mode's dtype is <class 'str'>
# speechiness's dtype is <class 'numpy.float64'>
# tempo's dtype is <class 'str'>
# valence's dtype is <class 'numpy.float64'>
# music_genre's dtype is <class 'str'>

# %%
abs(-1)
# Out:
# 1
